# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
history_csv = "./model/history.csv"

# %%
history_df = pd.read_csv(history_csv)
history_df.head(5)
# Out:
#    epoch  train_loss  valid_loss     lr  AUC_class1  AUC_class2  AUC_class3  \
# 0    0.0    0.081204    0.050230  0.001    0.520743    0.492324    0.471226
# 1    1.0    0.050991    0.062707  0.001    0.506176    0.510324    0.516696
# 2    2.0    0.043835    0.063786  0.001    0.484596    0.507386    0.511532
# 3    3.0    0.042725    0.056513  0.001    0.502719    0.494703    0.542997
# 4    4.0    0.042070    0.065840  0.001    0.507502    0.518715    0.502861
#
#    AP_class1  AP_class2  AP_class3
# 0   0.918614   0.066525   0.017852
# 1   0.917547   0.068263   0.022440
# 2   0.912995   0.071781   0.025937
# 3   0.917119   0.072785   0.022577
# 4   0.918616   0.072787   0.020538

# %%
# %pwd

# %%
# print the epoch number, training loss, validation loss and learning rate

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']) :3d}:  training loss {row['train_loss']:6.3f}  " \
            f"validation loss {row['valid_loss']:6.3f}  " \
            f"learning rate {row['lr']:10.7f} ")
    #print(f"epoch {int(row['epoch']) :4d}")
# Out:
# epoch   0:  training loss  0.081  validation loss  0.050  learning rate  0.0010000
# epoch   1:  training loss  0.051  validation loss  0.063  learning rate  0.0010000
# epoch   2:  training loss  0.044  validation loss  0.064  learning rate  0.0010000
# epoch   3:  training loss  0.043  validation loss  0.057  learning rate  0.0010000
# epoch   4:  training loss  0.042  validation loss  0.066  learning rate  0.0010000
# epoch   5:  training loss  0.042  validation loss  0.055  learning rate  0.0010000
# epoch   6:  training loss  0.042  validation loss  0.075  learning rate  0.0010000
# epoch   7:  training loss  0.042  validation loss  0.079  learning rate  0.0010000
# epoch   8:  training loss  0.042  validation loss  0.137  learning rate  0.0010000
# epoch   9:  training loss  0.046  validation loss  0.099  learning rate  0.0001000
# epoch  10:  training loss  0.043  validation loss  0.089  learning rate  0.0001000
# epoch  11:  training loss  0.042  validation loss  0.097  learning rate  0.0001000
# epoch  12:  training loss  0.042  validation loss  0.095  learning rate  0.0001000
# epoch  13:  training loss  0.042  validation loss  0.108  learning rate  0.0001000
# epoch  14:  training loss  0.042  validation loss  0.105  learning rate  0.0001000
# epoch  15:  training loss  0.042  validation loss  0.108  learning rate  0.0001000
# epoch  16:  training loss  0.042  validation loss  0.106  learning rate  0.0001000
# epoch  17:  training loss  0.043  validation loss  0.119  learning rate  0.0000100
# epoch  18:  training loss  0.042  validation loss  0.114  learning rate  0.0000100
# epoch  19:  training loss  0.042  validation loss  0.114  learning rate  0.0000100
# epoch  20:  training loss  0.042  validation loss  0.124  learning rate  0.0000100
# epoch  21:  training loss  0.042  validation loss  0.122  learning rate  0.0000100
# epoch  22:  training loss  0.042  validation loss  0.122  learning rate  0.0000100
# epoch  23:  training loss  0.042  validation loss  0.119  learning rate  0.0000100
# epoch  24:  training loss  0.042  validation loss  0.117  learning rate  0.0000100
# epoch  25:  training loss  0.042  validation loss  0.129  learning rate  0.0000010
# epoch  26:  training loss  0.042  validation loss  0.134  learning rate  0.0000010
# epoch  27:  training loss  0.042  validation loss  0.128  learning rate  0.0000010
# epoch  28:  training loss  0.042  validation loss  0.137  learning rate  0.0000010
# epoch  29:  training loss  0.042  validation loss  0.130  learning rate  0.0000010
# epoch  30:  training loss  0.042  validation loss  0.136  learning rate  0.0000010
# epoch  31:  training loss  0.042  validation loss  0.126  learning rate  0.0000010
# epoch  32:  training loss  0.042  validation loss  0.131  learning rate  0.0000010
# epoch  33:  training loss  0.042  validation loss  0.139  learning rate  0.0000001
# epoch  34:  training loss  0.042  validation loss  0.127  learning rate  0.0000001
# epoch  35:  training loss  0.042  validation loss  0.131  learning rate  0.0000001
# epoch  36:  training loss  0.042  validation loss  0.135  learning rate  0.0000001
# epoch  37:  training loss  0.042  validation loss  0.125  learning rate  0.0000001
# epoch  38:  training loss  0.042  validation loss  0.127  learning rate  0.0000001
# epoch  39:  training loss  0.042  validation loss  0.129  learning rate  0.0000001
# epoch  40:  training loss  0.042  validation loss  0.126  learning rate  0.0000001

# %%
# print the epoch number, validation loss and AUC-Score for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AUC class_1 {row['AUC_class1']:6.3f}  " \
            f"AUC class_2 {row['AUC_class2']:6.3f}  " \
            f"AUC class_3 {row['AUC_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.050  AUC class_1  0.521  AUC class_2  0.492  AUC class_3  0.471
# epoch   1:  validation loss  0.063  AUC class_1  0.506  AUC class_2  0.510  AUC class_3  0.517
# epoch   2:  validation loss  0.064  AUC class_1  0.485  AUC class_2  0.507  AUC class_3  0.512
# epoch   3:  validation loss  0.057  AUC class_1  0.503  AUC class_2  0.495  AUC class_3  0.543
# epoch   4:  validation loss  0.066  AUC class_1  0.508  AUC class_2  0.519  AUC class_3  0.503
# epoch   5:  validation loss  0.055  AUC class_1  0.511  AUC class_2  0.517  AUC class_3  0.501
# epoch   6:  validation loss  0.075  AUC class_1  0.539  AUC class_2  0.547  AUC class_3  0.487
# epoch   7:  validation loss  0.079  AUC class_1  0.539  AUC class_2  0.543  AUC class_3  0.493
# epoch   8:  validation loss  0.137  AUC class_1  0.543  AUC class_2  0.557  AUC class_3  0.519
# epoch   9:  validation loss  0.099  AUC class_1  0.572  AUC class_2  0.596  AUC class_3  0.494
# epoch  10:  validation loss  0.089  AUC class_1  0.560  AUC class_2  0.584  AUC class_3  0.527
# epoch  11:  validation loss  0.097  AUC class_1  0.563  AUC class_2  0.586  AUC class_3  0.517
# epoch  12:  validation loss  0.095  AUC class_1  0.558  AUC class_2  0.579  AUC class_3  0.517
# epoch  13:  validation loss  0.108  AUC class_1  0.559  AUC class_2  0.580  AUC class_3  0.510
# epoch  14:  validation loss  0.105  AUC class_1  0.559  AUC class_2  0.581  AUC class_3  0.522
# epoch  15:  validation loss  0.108  AUC class_1  0.563  AUC class_2  0.587  AUC class_3  0.515
# epoch  16:  validation loss  0.106  AUC class_1  0.562  AUC class_2  0.584  AUC class_3  0.526
# epoch  17:  validation loss  0.119  AUC class_1  0.562  AUC class_2  0.585  AUC class_3  0.530
# epoch  18:  validation loss  0.114  AUC class_1  0.566  AUC class_2  0.586  AUC class_3  0.507
# epoch  19:  validation loss  0.114  AUC class_1  0.568  AUC class_2  0.591  AUC class_3  0.502
# epoch  20:  validation loss  0.124  AUC class_1  0.572  AUC class_2  0.593  AUC class_3  0.494
# epoch  21:  validation loss  0.122  AUC class_1  0.575  AUC class_2  0.597  AUC class_3  0.491
# epoch  22:  validation loss  0.122  AUC class_1  0.575  AUC class_2  0.597  AUC class_3  0.489
# epoch  23:  validation loss  0.119  AUC class_1  0.577  AUC class_2  0.595  AUC class_3  0.488
# epoch  24:  validation loss  0.117  AUC class_1  0.548  AUC class_2  0.562  AUC class_3  0.497
# epoch  25:  validation loss  0.129  AUC class_1  0.549  AUC class_2  0.563  AUC class_3  0.486
# epoch  26:  validation loss  0.134  AUC class_1  0.576  AUC class_2  0.595  AUC class_3  0.485
# epoch  27:  validation loss  0.128  AUC class_1  0.556  AUC class_2  0.573  AUC class_3  0.492
# epoch  28:  validation loss  0.137  AUC class_1  0.550  AUC class_2  0.566  AUC class_3  0.492
# epoch  29:  validation loss  0.130  AUC class_1  0.546  AUC class_2  0.562  AUC class_3  0.492
# epoch  30:  validation loss  0.136  AUC class_1  0.578  AUC class_2  0.600  AUC class_3  0.486
# epoch  31:  validation loss  0.126  AUC class_1  0.548  AUC class_2  0.563  AUC class_3  0.495
# epoch  32:  validation loss  0.131  AUC class_1  0.551  AUC class_2  0.566  AUC class_3  0.486
# epoch  33:  validation loss  0.139  AUC class_1  0.556  AUC class_2  0.576  AUC class_3  0.490
# epoch  34:  validation loss  0.127  AUC class_1  0.544  AUC class_2  0.560  AUC class_3  0.494
# epoch  35:  validation loss  0.131  AUC class_1  0.559  AUC class_2  0.577  AUC class_3  0.492
# epoch  36:  validation loss  0.135  AUC class_1  0.549  AUC class_2  0.565  AUC class_3  0.490
# epoch  37:  validation loss  0.125  AUC class_1  0.550  AUC class_2  0.564  AUC class_3  0.489
# epoch  38:  validation loss  0.127  AUC class_1  0.549  AUC class_2  0.565  AUC class_3  0.486
# epoch  39:  validation loss  0.129  AUC class_1  0.545  AUC class_2  0.560  AUC class_3  0.495
# epoch  40:  validation loss  0.126  AUC class_1  0.564  AUC class_2  0.583  AUC class_3  0.489

# %%
# print the epoch number, validation loss and Average Precision for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AP class_1 {row['AP_class1']:6.3f}  " \
            f"AP class_2 {row['AP_class2']:6.3f}  " \
            f"AP class_3 {row['AP_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.050  AP class_1  0.919  AP class_2  0.067  AP class_3  0.018
# epoch   1:  validation loss  0.063  AP class_1  0.918  AP class_2  0.068  AP class_3  0.022
# epoch   2:  validation loss  0.064  AP class_1  0.913  AP class_2  0.072  AP class_3  0.026
# epoch   3:  validation loss  0.057  AP class_1  0.917  AP class_2  0.073  AP class_3  0.023
# epoch   4:  validation loss  0.066  AP class_1  0.919  AP class_2  0.073  AP class_3  0.021
# epoch   5:  validation loss  0.055  AP class_1  0.919  AP class_2  0.071  AP class_3  0.021
# epoch   6:  validation loss  0.075  AP class_1  0.924  AP class_2  0.076  AP class_3  0.020
# epoch   7:  validation loss  0.079  AP class_1  0.922  AP class_2  0.077  AP class_3  0.020
# epoch   8:  validation loss  0.137  AP class_1  0.925  AP class_2  0.078  AP class_3  0.025
# epoch   9:  validation loss  0.099  AP class_1  0.930  AP class_2  0.086  AP class_3  0.020
# epoch  10:  validation loss  0.089  AP class_1  0.927  AP class_2  0.084  AP class_3  0.023
# epoch  11:  validation loss  0.097  AP class_1  0.928  AP class_2  0.086  AP class_3  0.023
# epoch  12:  validation loss  0.095  AP class_1  0.927  AP class_2  0.083  AP class_3  0.023
# epoch  13:  validation loss  0.108  AP class_1  0.927  AP class_2  0.084  AP class_3  0.023
# epoch  14:  validation loss  0.105  AP class_1  0.927  AP class_2  0.084  AP class_3  0.023
# epoch  15:  validation loss  0.108  AP class_1  0.928  AP class_2  0.086  AP class_3  0.023
# epoch  16:  validation loss  0.106  AP class_1  0.928  AP class_2  0.085  AP class_3  0.024
# epoch  17:  validation loss  0.119  AP class_1  0.928  AP class_2  0.086  AP class_3  0.023
# epoch  18:  validation loss  0.114  AP class_1  0.929  AP class_2  0.085  AP class_3  0.021
# epoch  19:  validation loss  0.114  AP class_1  0.930  AP class_2  0.086  AP class_3  0.020
# epoch  20:  validation loss  0.124  AP class_1  0.931  AP class_2  0.087  AP class_3  0.020
# epoch  21:  validation loss  0.122  AP class_1  0.931  AP class_2  0.087  AP class_3  0.019
# epoch  22:  validation loss  0.122  AP class_1  0.931  AP class_2  0.087  AP class_3  0.020
# epoch  23:  validation loss  0.119  AP class_1  0.932  AP class_2  0.087  AP class_3  0.020
# epoch  24:  validation loss  0.117  AP class_1  0.925  AP class_2  0.079  AP class_3  0.020
# epoch  25:  validation loss  0.129  AP class_1  0.926  AP class_2  0.079  AP class_3  0.019
# epoch  26:  validation loss  0.134  AP class_1  0.932  AP class_2  0.088  AP class_3  0.019
# epoch  27:  validation loss  0.128  AP class_1  0.927  AP class_2  0.081  AP class_3  0.019
# epoch  28:  validation loss  0.137  AP class_1  0.926  AP class_2  0.080  AP class_3  0.019
# epoch  29:  validation loss  0.130  AP class_1  0.925  AP class_2  0.079  AP class_3  0.019
# epoch  30:  validation loss  0.136  AP class_1  0.931  AP class_2  0.089  AP class_3  0.019
# epoch  31:  validation loss  0.126  AP class_1  0.925  AP class_2  0.079  AP class_3  0.019
# epoch  32:  validation loss  0.131  AP class_1  0.926  AP class_2  0.080  AP class_3  0.019
# epoch  33:  validation loss  0.139  AP class_1  0.928  AP class_2  0.082  AP class_3  0.019
# epoch  34:  validation loss  0.127  AP class_1  0.924  AP class_2  0.078  AP class_3  0.019
# epoch  35:  validation loss  0.131  AP class_1  0.928  AP class_2  0.083  AP class_3  0.019
# epoch  36:  validation loss  0.135  AP class_1  0.926  AP class_2  0.080  AP class_3  0.019
# epoch  37:  validation loss  0.125  AP class_1  0.926  AP class_2  0.079  AP class_3  0.019
# epoch  38:  validation loss  0.127  AP class_1  0.926  AP class_2  0.079  AP class_3  0.019
# epoch  39:  validation loss  0.129  AP class_1  0.925  AP class_2  0.078  AP class_3  0.019
# epoch  40:  validation loss  0.126  AP class_1  0.929  AP class_2  0.084  AP class_3  0.019

# %%
# plot the cross-entropy

plt.plot(history_df["epoch"], history_df["train_loss"], 'b-', label='Training loss')
plt.plot(history_df["epoch"], history_df["valid_loss"], 'r-', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Cross-entropy loss')
#plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy Loss')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the AUC Score

plt.plot(history_df["epoch"], history_df["AUC_class1"], 'b-', label='AUC class_1')
plt.plot(history_df["epoch"], history_df["AUC_class2"], 'r-', label='AUC class_2')
plt.plot(history_df["epoch"], history_df["AUC_class3"], 'g-', label='AUC class_3')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('AUC Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the Average Preision Score

plt.plot(history_df["epoch"], history_df["AP_class1"], 'b-', label='AP class_1')
plt.plot(history_df["epoch"], history_df["AP_class2"], 'r-', label='AP class_2')
plt.plot(history_df["epoch"], history_df["AP_class3"], 'y-', label='AP class_3')
plt.xlabel('Epoch')
plt.ylabel('AP Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Average Preision Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()
