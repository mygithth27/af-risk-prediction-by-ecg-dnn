# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
history_csv = "./previousModel/model_23Mar/history.csv"

# %%
history_df = pd.read_csv(history_csv)
history_df.head(5)
# Out:
#    epoch  train_loss  valid_loss     lr  AUC_class1  AUC_class2  AUC_class3  \
# 0    0.0    0.085862    0.075793  0.001    0.514479    0.503920    0.512604
# 1    1.0    0.055715    0.053856  0.001    0.457896    0.493614    0.528331
# 2    2.0    0.044206    0.060470  0.001    0.537288    0.560090    0.478715
# 3    3.0    0.042906    0.059195  0.001    0.552366    0.575944    0.489384
# 4    4.0    0.042520    0.068693  0.001    0.566564    0.570113    0.483190
#
#    AP_class1  AP_class2  AP_class3
# 0   0.916600   0.067052   0.022679
# 1   0.906470   0.064341   0.022880
# 2   0.920726   0.092789   0.019525
# 3   0.925761   0.094542   0.019533
# 4   0.925546   0.088445   0.019458

# %%
# %pwd

# %%
# print the epoch number, training loss, validation loss and learning rate

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']) :3d}:  training loss {row['train_loss']:6.3f}  " \
            f"validation loss {row['valid_loss']:6.3f}  " \
            f"learning rate {row['lr']:10.7f} ")
    #print(f"epoch {int(row['epoch']) :4d}")
# Out:
# epoch   0:  training loss  0.086  validation loss  0.076  learning rate  0.0010000
# epoch   1:  training loss  0.056  validation loss  0.054  learning rate  0.0010000
# epoch   2:  training loss  0.044  validation loss  0.060  learning rate  0.0010000
# epoch   3:  training loss  0.043  validation loss  0.059  learning rate  0.0010000
# epoch   4:  training loss  0.043  validation loss  0.069  learning rate  0.0010000
# epoch   5:  training loss  0.042  validation loss  0.056  learning rate  0.0010000
# epoch   6:  training loss  0.042  validation loss  0.052  learning rate  0.0010000
# epoch   7:  training loss  0.041  validation loss  0.046  learning rate  0.0010000
# epoch   8:  training loss  0.040  validation loss  0.043  learning rate  0.0010000
# epoch   9:  training loss  0.039  validation loss  0.050  learning rate  0.0010000
# epoch  10:  training loss  0.040  validation loss  0.048  learning rate  0.0010000
# epoch  11:  training loss  0.039  validation loss  0.040  learning rate  0.0010000
# epoch  12:  training loss  0.037  validation loss  0.046  learning rate  0.0010000
# epoch  13:  training loss  0.037  validation loss  0.038  learning rate  0.0010000
# epoch  14:  training loss  0.036  validation loss  0.036  learning rate  0.0010000
# epoch  15:  training loss  0.034  validation loss  0.033  learning rate  0.0010000
# epoch  16:  training loss  0.031  validation loss  0.043  learning rate  0.0010000
# epoch  17:  training loss  0.028  validation loss  0.041  learning rate  0.0010000
# epoch  18:  training loss  0.027  validation loss  0.033  learning rate  0.0010000
# epoch  19:  training loss  0.025  validation loss  0.040  learning rate  0.0010000
# epoch  20:  training loss  0.025  validation loss  0.044  learning rate  0.0010000
# epoch  21:  training loss  0.025  validation loss  0.052  learning rate  0.0010000
# epoch  22:  training loss  0.024  validation loss  0.053  learning rate  0.0010000
# epoch  23:  training loss  0.025  validation loss  0.051  learning rate  0.0010000
# epoch  24:  training loss  0.025  validation loss  0.047  learning rate  0.0001000
# epoch  25:  training loss  0.023  validation loss  0.049  learning rate  0.0001000
# epoch  26:  training loss  0.023  validation loss  0.052  learning rate  0.0001000
# epoch  27:  training loss  0.023  validation loss  0.048  learning rate  0.0001000
# epoch  28:  training loss  0.022  validation loss  0.054  learning rate  0.0001000
# epoch  29:  training loss  0.023  validation loss  0.059  learning rate  0.0001000
# epoch  30:  training loss  0.022  validation loss  0.059  learning rate  0.0001000
# epoch  31:  training loss  0.022  validation loss  0.057  learning rate  0.0001000
# epoch  32:  training loss  0.024  validation loss  0.060  learning rate  0.0000100
# epoch  33:  training loss  0.022  validation loss  0.064  learning rate  0.0000100
# epoch  34:  training loss  0.023  validation loss  0.065  learning rate  0.0000100
# epoch  35:  training loss  0.022  validation loss  0.059  learning rate  0.0000100
# epoch  36:  training loss  0.023  validation loss  0.066  learning rate  0.0000100
# epoch  37:  training loss  0.022  validation loss  0.058  learning rate  0.0000100
# epoch  38:  training loss  0.022  validation loss  0.060  learning rate  0.0000100
# epoch  39:  training loss  0.022  validation loss  0.072  learning rate  0.0000100
# epoch  40:  training loss  0.022  validation loss  0.057  learning rate  0.0000010
# epoch  41:  training loss  0.022  validation loss  0.061  learning rate  0.0000010
# epoch  42:  training loss  0.022  validation loss  0.057  learning rate  0.0000010
# epoch  43:  training loss  0.022  validation loss  0.066  learning rate  0.0000010
# epoch  44:  training loss  0.023  validation loss  0.073  learning rate  0.0000010
# epoch  45:  training loss  0.022  validation loss  0.066  learning rate  0.0000010
# epoch  46:  training loss  0.022  validation loss  0.068  learning rate  0.0000010
# epoch  47:  training loss  0.022  validation loss  0.068  learning rate  0.0000010
# epoch  48:  training loss  0.023  validation loss  0.070  learning rate  0.0000001
# epoch  49:  training loss  0.023  validation loss  0.069  learning rate  0.0000001
# epoch  50:  training loss  0.023  validation loss  0.063  learning rate  0.0000001
# epoch  51:  training loss  0.022  validation loss  0.071  learning rate  0.0000001
# epoch  52:  training loss  0.022  validation loss  0.066  learning rate  0.0000001
# epoch  53:  training loss  0.022  validation loss  0.064  learning rate  0.0000001
# epoch  54:  training loss  0.022  validation loss  0.055  learning rate  0.0000001
# epoch  55:  training loss  0.022  validation loss  0.058  learning rate  0.0000001

# %%
# print the epoch number, validation loss and AUC-Score for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AUC class_1 {row['AUC_class1']:6.3f}  " \
            f"AUC class_2 {row['AUC_class2']:6.3f}  " \
            f"AUC class_3 {row['AUC_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.076  AUC class_1  0.514  AUC class_2  0.504  AUC class_3  0.513
# epoch   1:  validation loss  0.054  AUC class_1  0.458  AUC class_2  0.494  AUC class_3  0.528
# epoch   2:  validation loss  0.060  AUC class_1  0.537  AUC class_2  0.560  AUC class_3  0.479
# epoch   3:  validation loss  0.059  AUC class_1  0.552  AUC class_2  0.576  AUC class_3  0.489
# epoch   4:  validation loss  0.069  AUC class_1  0.567  AUC class_2  0.570  AUC class_3  0.483
# epoch   5:  validation loss  0.056  AUC class_1  0.650  AUC class_2  0.657  AUC class_3  0.431
# epoch   6:  validation loss  0.052  AUC class_1  0.699  AUC class_2  0.710  AUC class_3  0.381
# epoch   7:  validation loss  0.046  AUC class_1  0.676  AUC class_2  0.714  AUC class_3  0.507
# epoch   8:  validation loss  0.043  AUC class_1  0.711  AUC class_2  0.747  AUC class_3  0.401
# epoch   9:  validation loss  0.050  AUC class_1  0.745  AUC class_2  0.744  AUC class_3  0.378
# epoch  10:  validation loss  0.048  AUC class_1  0.754  AUC class_2  0.764  AUC class_3  0.375
# epoch  11:  validation loss  0.040  AUC class_1  0.767  AUC class_2  0.782  AUC class_3  0.461
# epoch  12:  validation loss  0.046  AUC class_1  0.778  AUC class_2  0.792  AUC class_3  0.475
# epoch  13:  validation loss  0.038  AUC class_1  0.723  AUC class_2  0.708  AUC class_3  0.443
# epoch  14:  validation loss  0.036  AUC class_1  0.826  AUC class_2  0.769  AUC class_3  0.399
# epoch  15:  validation loss  0.033  AUC class_1  0.855  AUC class_2  0.902  AUC class_3  0.420
# epoch  16:  validation loss  0.043  AUC class_1  0.883  AUC class_2  0.894  AUC class_3  0.415
# epoch  17:  validation loss  0.041  AUC class_1  0.871  AUC class_2  0.916  AUC class_3  0.546
# epoch  18:  validation loss  0.033  AUC class_1  0.873  AUC class_2  0.915  AUC class_3  0.486
# epoch  19:  validation loss  0.040  AUC class_1  0.835  AUC class_2  0.907  AUC class_3  0.538
# epoch  20:  validation loss  0.044  AUC class_1  0.847  AUC class_2  0.913  AUC class_3  0.505
# epoch  21:  validation loss  0.052  AUC class_1  0.834  AUC class_2  0.899  AUC class_3  0.546
# epoch  22:  validation loss  0.053  AUC class_1  0.849  AUC class_2  0.917  AUC class_3  0.433
# epoch  23:  validation loss  0.051  AUC class_1  0.779  AUC class_2  0.870  AUC class_3  0.494
# epoch  24:  validation loss  0.047  AUC class_1  0.861  AUC class_2  0.927  AUC class_3  0.645
# epoch  25:  validation loss  0.049  AUC class_1  0.857  AUC class_2  0.919  AUC class_3  0.640
# epoch  26:  validation loss  0.052  AUC class_1  0.851  AUC class_2  0.915  AUC class_3  0.654
# epoch  27:  validation loss  0.048  AUC class_1  0.862  AUC class_2  0.929  AUC class_3  0.648
# epoch  28:  validation loss  0.054  AUC class_1  0.843  AUC class_2  0.913  AUC class_3  0.649
# epoch  29:  validation loss  0.059  AUC class_1  0.849  AUC class_2  0.916  AUC class_3  0.638
# epoch  30:  validation loss  0.059  AUC class_1  0.843  AUC class_2  0.910  AUC class_3  0.646
# epoch  31:  validation loss  0.057  AUC class_1  0.838  AUC class_2  0.920  AUC class_3  0.637
# epoch  32:  validation loss  0.060  AUC class_1  0.844  AUC class_2  0.927  AUC class_3  0.655
# epoch  33:  validation loss  0.064  AUC class_1  0.841  AUC class_2  0.924  AUC class_3  0.655
# epoch  34:  validation loss  0.065  AUC class_1  0.839  AUC class_2  0.922  AUC class_3  0.655
# epoch  35:  validation loss  0.059  AUC class_1  0.852  AUC class_2  0.924  AUC class_3  0.668
# epoch  36:  validation loss  0.066  AUC class_1  0.846  AUC class_2  0.919  AUC class_3  0.663
# epoch  37:  validation loss  0.058  AUC class_1  0.847  AUC class_2  0.923  AUC class_3  0.663
# epoch  38:  validation loss  0.060  AUC class_1  0.845  AUC class_2  0.921  AUC class_3  0.661
# epoch  39:  validation loss  0.072  AUC class_1  0.836  AUC class_2  0.913  AUC class_3  0.659
# epoch  40:  validation loss  0.057  AUC class_1  0.846  AUC class_2  0.923  AUC class_3  0.661
# epoch  41:  validation loss  0.061  AUC class_1  0.849  AUC class_2  0.920  AUC class_3  0.666
# epoch  42:  validation loss  0.057  AUC class_1  0.850  AUC class_2  0.923  AUC class_3  0.667
# epoch  43:  validation loss  0.066  AUC class_1  0.841  AUC class_2  0.916  AUC class_3  0.661
# epoch  44:  validation loss  0.073  AUC class_1  0.842  AUC class_2  0.914  AUC class_3  0.664
# epoch  45:  validation loss  0.066  AUC class_1  0.841  AUC class_2  0.917  AUC class_3  0.662
# epoch  46:  validation loss  0.068  AUC class_1  0.849  AUC class_2  0.917  AUC class_3  0.664
# epoch  47:  validation loss  0.068  AUC class_1  0.846  AUC class_2  0.917  AUC class_3  0.664
# epoch  48:  validation loss  0.070  AUC class_1  0.830  AUC class_2  0.916  AUC class_3  0.655
# epoch  49:  validation loss  0.069  AUC class_1  0.845  AUC class_2  0.917  AUC class_3  0.667
# epoch  50:  validation loss  0.063  AUC class_1  0.851  AUC class_2  0.921  AUC class_3  0.670
# epoch  51:  validation loss  0.071  AUC class_1  0.843  AUC class_2  0.916  AUC class_3  0.664
# epoch  52:  validation loss  0.066  AUC class_1  0.844  AUC class_2  0.918  AUC class_3  0.662
# epoch  53:  validation loss  0.064  AUC class_1  0.850  AUC class_2  0.919  AUC class_3  0.669
# epoch  54:  validation loss  0.055  AUC class_1  0.856  AUC class_2  0.924  AUC class_3  0.672
# epoch  55:  validation loss  0.058  AUC class_1  0.851  AUC class_2  0.923  AUC class_3  0.670

# %%
# print the epoch number, validation loss and Average Precision for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AP class_1 {row['AP_class1']:6.3f}  " \
            f"AP class_2 {row['AP_class2']:6.3f}  " \
            f"AP class_3 {row['AP_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.076  AP class_1  0.917  AP class_2  0.067  AP class_3  0.023
# epoch   1:  validation loss  0.054  AP class_1  0.906  AP class_2  0.064  AP class_3  0.023
# epoch   2:  validation loss  0.060  AP class_1  0.921  AP class_2  0.093  AP class_3  0.020
# epoch   3:  validation loss  0.059  AP class_1  0.926  AP class_2  0.095  AP class_3  0.020
# epoch   4:  validation loss  0.069  AP class_1  0.926  AP class_2  0.088  AP class_3  0.019
# epoch   5:  validation loss  0.056  AP class_1  0.938  AP class_2  0.135  AP class_3  0.017
# epoch   6:  validation loss  0.052  AP class_1  0.948  AP class_2  0.181  AP class_3  0.015
# epoch   7:  validation loss  0.046  AP class_1  0.938  AP class_2  0.219  AP class_3  0.020
# epoch   8:  validation loss  0.043  AP class_1  0.947  AP class_2  0.235  AP class_3  0.018
# epoch   9:  validation loss  0.050  AP class_1  0.953  AP class_2  0.270  AP class_3  0.015
# epoch  10:  validation loss  0.048  AP class_1  0.954  AP class_2  0.279  AP class_3  0.015
# epoch  11:  validation loss  0.040  AP class_1  0.958  AP class_2  0.288  AP class_3  0.019
# epoch  12:  validation loss  0.046  AP class_1  0.960  AP class_2  0.316  AP class_3  0.019
# epoch  13:  validation loss  0.038  AP class_1  0.949  AP class_2  0.261  AP class_3  0.017
# epoch  14:  validation loss  0.036  AP class_1  0.968  AP class_2  0.337  AP class_3  0.016
# epoch  15:  validation loss  0.033  AP class_1  0.973  AP class_2  0.464  AP class_3  0.017
# epoch  16:  validation loss  0.043  AP class_1  0.976  AP class_2  0.591  AP class_3  0.017
# epoch  17:  validation loss  0.041  AP class_1  0.973  AP class_2  0.607  AP class_3  0.022
# epoch  18:  validation loss  0.033  AP class_1  0.973  AP class_2  0.605  AP class_3  0.021
# epoch  19:  validation loss  0.040  AP class_1  0.967  AP class_2  0.579  AP class_3  0.024
# epoch  20:  validation loss  0.044  AP class_1  0.969  AP class_2  0.641  AP class_3  0.021
# epoch  21:  validation loss  0.052  AP class_1  0.966  AP class_2  0.602  AP class_3  0.024
# epoch  22:  validation loss  0.053  AP class_1  0.968  AP class_2  0.596  AP class_3  0.018
# epoch  23:  validation loss  0.051  AP class_1  0.958  AP class_2  0.509  AP class_3  0.021
# epoch  24:  validation loss  0.047  AP class_1  0.972  AP class_2  0.621  AP class_3  0.039
# epoch  25:  validation loss  0.049  AP class_1  0.972  AP class_2  0.608  AP class_3  0.039
# epoch  26:  validation loss  0.052  AP class_1  0.970  AP class_2  0.577  AP class_3  0.041
# epoch  27:  validation loss  0.048  AP class_1  0.973  AP class_2  0.617  AP class_3  0.039
# epoch  28:  validation loss  0.054  AP class_1  0.969  AP class_2  0.568  AP class_3  0.040
# epoch  29:  validation loss  0.059  AP class_1  0.969  AP class_2  0.595  AP class_3  0.038
# epoch  30:  validation loss  0.059  AP class_1  0.969  AP class_2  0.573  AP class_3  0.039
# epoch  31:  validation loss  0.057  AP class_1  0.968  AP class_2  0.575  AP class_3  0.040
# epoch  32:  validation loss  0.060  AP class_1  0.968  AP class_2  0.618  AP class_3  0.041
# epoch  33:  validation loss  0.064  AP class_1  0.967  AP class_2  0.611  AP class_3  0.041
# epoch  34:  validation loss  0.065  AP class_1  0.967  AP class_2  0.605  AP class_3  0.041
# epoch  35:  validation loss  0.059  AP class_1  0.969  AP class_2  0.596  AP class_3  0.045
# epoch  36:  validation loss  0.066  AP class_1  0.968  AP class_2  0.593  AP class_3  0.043
# epoch  37:  validation loss  0.058  AP class_1  0.969  AP class_2  0.596  AP class_3  0.043
# epoch  38:  validation loss  0.060  AP class_1  0.968  AP class_2  0.587  AP class_3  0.043
# epoch  39:  validation loss  0.072  AP class_1  0.966  AP class_2  0.583  AP class_3  0.042
# epoch  40:  validation loss  0.057  AP class_1  0.969  AP class_2  0.594  AP class_3  0.043
# epoch  41:  validation loss  0.061  AP class_1  0.969  AP class_2  0.590  AP class_3  0.043
# epoch  42:  validation loss  0.057  AP class_1  0.969  AP class_2  0.597  AP class_3  0.044
# epoch  43:  validation loss  0.066  AP class_1  0.967  AP class_2  0.590  AP class_3  0.043
# epoch  44:  validation loss  0.073  AP class_1  0.967  AP class_2  0.586  AP class_3  0.043
# epoch  45:  validation loss  0.066  AP class_1  0.967  AP class_2  0.588  AP class_3  0.044
# epoch  46:  validation loss  0.068  AP class_1  0.968  AP class_2  0.596  AP class_3  0.043
# epoch  47:  validation loss  0.068  AP class_1  0.968  AP class_2  0.593  AP class_3  0.043
# epoch  48:  validation loss  0.070  AP class_1  0.966  AP class_2  0.593  AP class_3  0.041
# epoch  49:  validation loss  0.069  AP class_1  0.968  AP class_2  0.589  AP class_3  0.044
# epoch  50:  validation loss  0.063  AP class_1  0.969  AP class_2  0.594  AP class_3  0.044
# epoch  51:  validation loss  0.071  AP class_1  0.967  AP class_2  0.590  AP class_3  0.043
# epoch  52:  validation loss  0.066  AP class_1  0.968  AP class_2  0.596  AP class_3  0.043
# epoch  53:  validation loss  0.064  AP class_1  0.969  AP class_2  0.589  AP class_3  0.044
# epoch  54:  validation loss  0.055  AP class_1  0.970  AP class_2  0.596  AP class_3  0.044
# epoch  55:  validation loss  0.058  AP class_1  0.969  AP class_2  0.592  AP class_3  0.044

# %%
# plot the cross-entropy

plt.plot(history_df["epoch"], history_df["train_loss"], 'b-', label='Training loss')
plt.plot(history_df["epoch"], history_df["valid_loss"], 'r-', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Cross-entropy loss')
#plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy Loss')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the AUC Score

plt.plot(history_df["epoch"], history_df["AUC_class1"], 'b-', label='AUC class_1')
plt.plot(history_df["epoch"], history_df["AUC_class2"], 'r-', label='AUC class_2')
plt.plot(history_df["epoch"], history_df["AUC_class3"], 'g-', label='AUC class_3')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('AUC Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the Average Preision Score

plt.plot(history_df["epoch"], history_df["AP_class1"], 'b-', label='AP class_1')
plt.plot(history_df["epoch"], history_df["AP_class2"], 'r-', label='AP class_2')
plt.plot(history_df["epoch"], history_df["AP_class3"], 'y-', label='AP class_3')
plt.xlabel('Epoch')
plt.ylabel('AP Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Average Preision Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()
