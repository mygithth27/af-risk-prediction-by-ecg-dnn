# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
history_csv = "./previousModel/model_22Mar/history.csv"

# %%
history_df = pd.read_csv(history_csv)
history_df.head(5)
# Out:
#    epoch  train_loss  valid_loss     lr  AUC_class1  AUC_class2  AUC_class3  \
# 0    0.0    0.077477    0.062448  0.001    0.445174    0.494317    0.548712
# 1    1.0    0.057031    0.057838  0.001    0.526345    0.548091    0.488307
# 2    2.0    0.045482    0.062796  0.001    0.433240    0.478112    0.547922
# 3    3.0    0.042965    0.069260  0.001    0.460035    0.509966    0.548337
# 4    4.0    0.041804    0.051493  0.001    0.495070    0.505216    0.542608
#
#    AP_class1  AP_class2  AP_class3
# 0   0.900485   0.064447   0.024437
# 1   0.920093   0.077659   0.019870
# 2   0.901595   0.062411   0.025150
# 3   0.903110   0.068238   0.024705
# 4   0.919397   0.065138   0.023920

# %%
# %pwd

# %%
# print the epoch number, training loss, validation loss and learning rate

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']) :3d}:  training loss {row['train_loss']:6.3f}  " \
            f"validation loss {row['valid_loss']:6.3f}  " \
            f"learning rate {row['lr']:10.7f} ")
    #print(f"epoch {int(row['epoch']) :4d}")
# Out:
# epoch   0:  training loss  0.077  validation loss  0.062  learning rate  0.0010000
# epoch   1:  training loss  0.057  validation loss  0.058  learning rate  0.0010000
# epoch   2:  training loss  0.045  validation loss  0.063  learning rate  0.0010000
# epoch   3:  training loss  0.043  validation loss  0.069  learning rate  0.0010000
# epoch   4:  training loss  0.042  validation loss  0.051  learning rate  0.0010000
# epoch   5:  training loss  0.041  validation loss  0.045  learning rate  0.0010000
# epoch   6:  training loss  0.041  validation loss  0.043  learning rate  0.0010000
# epoch   7:  training loss  0.041  validation loss  0.039  learning rate  0.0010000
# epoch   8:  training loss  0.040  validation loss  0.040  learning rate  0.0010000
# epoch   9:  training loss  0.039  validation loss  0.036  learning rate  0.0010000
# epoch  10:  training loss  0.039  validation loss  0.034  learning rate  0.0010000
# epoch  11:  training loss  0.038  validation loss  0.035  learning rate  0.0010000
# epoch  12:  training loss  0.035  validation loss  0.036  learning rate  0.0010000
# epoch  13:  training loss  0.032  validation loss  0.067  learning rate  0.0010000
# epoch  14:  training loss  0.029  validation loss  0.076  learning rate  0.0010000
# epoch  15:  training loss  0.028  validation loss  0.045  learning rate  0.0010000
# epoch  16:  training loss  0.026  validation loss  0.036  learning rate  0.0010000
# epoch  17:  training loss  0.025  validation loss  0.034  learning rate  0.0010000
# epoch  18:  training loss  0.025  validation loss  0.038  learning rate  0.0010000
# epoch  19:  training loss  0.027  validation loss  0.022  learning rate  0.0001000
# epoch  20:  training loss  0.024  validation loss  0.023  learning rate  0.0001000
# epoch  21:  training loss  0.024  validation loss  0.025  learning rate  0.0001000
# epoch  22:  training loss  0.023  validation loss  0.024  learning rate  0.0001000
# epoch  23:  training loss  0.023  validation loss  0.027  learning rate  0.0001000
# epoch  24:  training loss  0.023  validation loss  0.031  learning rate  0.0001000
# epoch  25:  training loss  0.023  validation loss  0.027  learning rate  0.0001000
# epoch  26:  training loss  0.022  validation loss  0.031  learning rate  0.0001000
# epoch  27:  training loss  0.022  validation loss  0.034  learning rate  0.0001000
# epoch  28:  training loss  0.024  validation loss  0.037  learning rate  0.0000100
# epoch  29:  training loss  0.023  validation loss  0.037  learning rate  0.0000100
# epoch  30:  training loss  0.023  validation loss  0.035  learning rate  0.0000100
# epoch  31:  training loss  0.023  validation loss  0.035  learning rate  0.0000100
# epoch  32:  training loss  0.022  validation loss  0.035  learning rate  0.0000100
# epoch  33:  training loss  0.023  validation loss  0.036  learning rate  0.0000100
# epoch  34:  training loss  0.022  validation loss  0.036  learning rate  0.0000100
# epoch  35:  training loss  0.022  validation loss  0.037  learning rate  0.0000100
# epoch  36:  training loss  0.023  validation loss  0.038  learning rate  0.0000010
# epoch  37:  training loss  0.023  validation loss  0.037  learning rate  0.0000010
# epoch  38:  training loss  0.022  validation loss  0.038  learning rate  0.0000010
# epoch  39:  training loss  0.023  validation loss  0.037  learning rate  0.0000010
# epoch  40:  training loss  0.023  validation loss  0.039  learning rate  0.0000010
# epoch  41:  training loss  0.023  validation loss  0.039  learning rate  0.0000010
# epoch  42:  training loss  0.022  validation loss  0.037  learning rate  0.0000010
# epoch  43:  training loss  0.022  validation loss  0.039  learning rate  0.0000010
# epoch  44:  training loss  0.022  validation loss  0.037  learning rate  0.0000001
# epoch  45:  training loss  0.023  validation loss  0.038  learning rate  0.0000001
# epoch  46:  training loss  0.023  validation loss  0.038  learning rate  0.0000001
# epoch  47:  training loss  0.023  validation loss  0.037  learning rate  0.0000001
# epoch  48:  training loss  0.022  validation loss  0.038  learning rate  0.0000001
# epoch  49:  training loss  0.022  validation loss  0.039  learning rate  0.0000001
# epoch  50:  training loss  0.022  validation loss  0.040  learning rate  0.0000001
# epoch  51:  training loss  0.022  validation loss  0.040  learning rate  0.0000001

# %%
# print the epoch number, validation loss and AUC-Score for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AUC class_1 {row['AUC_class1']:6.3f}  " \
            f"AUC class_2 {row['AUC_class2']:6.3f}  " \
            f"AUC class_3 {row['AUC_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.062  AUC class_1  0.445  AUC class_2  0.494  AUC class_3  0.549
# epoch   1:  validation loss  0.058  AUC class_1  0.526  AUC class_2  0.548  AUC class_3  0.488
# epoch   2:  validation loss  0.063  AUC class_1  0.433  AUC class_2  0.478  AUC class_3  0.548
# epoch   3:  validation loss  0.069  AUC class_1  0.460  AUC class_2  0.510  AUC class_3  0.548
# epoch   4:  validation loss  0.051  AUC class_1  0.495  AUC class_2  0.505  AUC class_3  0.543
# epoch   5:  validation loss  0.045  AUC class_1  0.630  AUC class_2  0.648  AUC class_3  0.537
# epoch   6:  validation loss  0.043  AUC class_1  0.663  AUC class_2  0.677  AUC class_3  0.428
# epoch   7:  validation loss  0.039  AUC class_1  0.656  AUC class_2  0.684  AUC class_3  0.487
# epoch   8:  validation loss  0.040  AUC class_1  0.682  AUC class_2  0.701  AUC class_3  0.530
# epoch   9:  validation loss  0.036  AUC class_1  0.738  AUC class_2  0.747  AUC class_3  0.386
# epoch  10:  validation loss  0.034  AUC class_1  0.765  AUC class_2  0.773  AUC class_3  0.349
# epoch  11:  validation loss  0.035  AUC class_1  0.780  AUC class_2  0.746  AUC class_3  0.369
# epoch  12:  validation loss  0.036  AUC class_1  0.811  AUC class_2  0.800  AUC class_3  0.370
# epoch  13:  validation loss  0.067  AUC class_1  0.827  AUC class_2  0.865  AUC class_3  0.446
# epoch  14:  validation loss  0.076  AUC class_1  0.835  AUC class_2  0.906  AUC class_3  0.370
# epoch  15:  validation loss  0.045  AUC class_1  0.884  AUC class_2  0.912  AUC class_3  0.437
# epoch  16:  validation loss  0.036  AUC class_1  0.901  AUC class_2  0.932  AUC class_3  0.540
# epoch  17:  validation loss  0.034  AUC class_1  0.899  AUC class_2  0.883  AUC class_3  0.437
# epoch  18:  validation loss  0.038  AUC class_1  0.895  AUC class_2  0.897  AUC class_3  0.420
# epoch  19:  validation loss  0.022  AUC class_1  0.916  AUC class_2  0.949  AUC class_3  0.501
# epoch  20:  validation loss  0.023  AUC class_1  0.919  AUC class_2  0.956  AUC class_3  0.543
# epoch  21:  validation loss  0.025  AUC class_1  0.919  AUC class_2  0.953  AUC class_3  0.536
# epoch  22:  validation loss  0.024  AUC class_1  0.915  AUC class_2  0.951  AUC class_3  0.546
# epoch  23:  validation loss  0.027  AUC class_1  0.912  AUC class_2  0.945  AUC class_3  0.573
# epoch  24:  validation loss  0.031  AUC class_1  0.912  AUC class_2  0.948  AUC class_3  0.574
# epoch  25:  validation loss  0.027  AUC class_1  0.906  AUC class_2  0.942  AUC class_3  0.578
# epoch  26:  validation loss  0.031  AUC class_1  0.901  AUC class_2  0.933  AUC class_3  0.558
# epoch  27:  validation loss  0.034  AUC class_1  0.904  AUC class_2  0.930  AUC class_3  0.576
# epoch  28:  validation loss  0.037  AUC class_1  0.889  AUC class_2  0.925  AUC class_3  0.619
# epoch  29:  validation loss  0.037  AUC class_1  0.887  AUC class_2  0.924  AUC class_3  0.606
# epoch  30:  validation loss  0.035  AUC class_1  0.889  AUC class_2  0.926  AUC class_3  0.609
# epoch  31:  validation loss  0.035  AUC class_1  0.889  AUC class_2  0.927  AUC class_3  0.604
# epoch  32:  validation loss  0.035  AUC class_1  0.889  AUC class_2  0.926  AUC class_3  0.608
# epoch  33:  validation loss  0.036  AUC class_1  0.885  AUC class_2  0.924  AUC class_3  0.607
# epoch  34:  validation loss  0.036  AUC class_1  0.888  AUC class_2  0.926  AUC class_3  0.622
# epoch  35:  validation loss  0.037  AUC class_1  0.888  AUC class_2  0.925  AUC class_3  0.619
# epoch  36:  validation loss  0.038  AUC class_1  0.884  AUC class_2  0.921  AUC class_3  0.605
# epoch  37:  validation loss  0.037  AUC class_1  0.888  AUC class_2  0.926  AUC class_3  0.625
# epoch  38:  validation loss  0.038  AUC class_1  0.884  AUC class_2  0.922  AUC class_3  0.618
# epoch  39:  validation loss  0.037  AUC class_1  0.884  AUC class_2  0.923  AUC class_3  0.620
# epoch  40:  validation loss  0.039  AUC class_1  0.883  AUC class_2  0.922  AUC class_3  0.616
# epoch  41:  validation loss  0.039  AUC class_1  0.882  AUC class_2  0.921  AUC class_3  0.617
# epoch  42:  validation loss  0.037  AUC class_1  0.885  AUC class_2  0.924  AUC class_3  0.619
# epoch  43:  validation loss  0.039  AUC class_1  0.882  AUC class_2  0.921  AUC class_3  0.619
# epoch  44:  validation loss  0.037  AUC class_1  0.885  AUC class_2  0.924  AUC class_3  0.620
# epoch  45:  validation loss  0.038  AUC class_1  0.883  AUC class_2  0.922  AUC class_3  0.619
# epoch  46:  validation loss  0.038  AUC class_1  0.885  AUC class_2  0.924  AUC class_3  0.621
# epoch  47:  validation loss  0.037  AUC class_1  0.886  AUC class_2  0.925  AUC class_3  0.629
# epoch  48:  validation loss  0.038  AUC class_1  0.885  AUC class_2  0.924  AUC class_3  0.621
# epoch  49:  validation loss  0.039  AUC class_1  0.884  AUC class_2  0.923  AUC class_3  0.625
# epoch  50:  validation loss  0.040  AUC class_1  0.881  AUC class_2  0.920  AUC class_3  0.611
# epoch  51:  validation loss  0.040  AUC class_1  0.881  AUC class_2  0.920  AUC class_3  0.620

# %%
# print the epoch number, validation loss and Average Precision for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AP class_1 {row['AP_class1']:6.3f}  " \
            f"AP class_2 {row['AP_class2']:6.3f}  " \
            f"AP class_3 {row['AP_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.062  AP class_1  0.900  AP class_2  0.064  AP class_3  0.024
# epoch   1:  validation loss  0.058  AP class_1  0.920  AP class_2  0.078  AP class_3  0.020
# epoch   2:  validation loss  0.063  AP class_1  0.902  AP class_2  0.062  AP class_3  0.025
# epoch   3:  validation loss  0.069  AP class_1  0.903  AP class_2  0.068  AP class_3  0.025
# epoch   4:  validation loss  0.051  AP class_1  0.919  AP class_2  0.065  AP class_3  0.024
# epoch   5:  validation loss  0.045  AP class_1  0.938  AP class_2  0.126  AP class_3  0.023
# epoch   6:  validation loss  0.043  AP class_1  0.941  AP class_2  0.177  AP class_3  0.017
# epoch   7:  validation loss  0.039  AP class_1  0.939  AP class_2  0.259  AP class_3  0.019
# epoch   8:  validation loss  0.040  AP class_1  0.943  AP class_2  0.297  AP class_3  0.022
# epoch   9:  validation loss  0.036  AP class_1  0.954  AP class_2  0.301  AP class_3  0.015
# epoch  10:  validation loss  0.034  AP class_1  0.963  AP class_2  0.281  AP class_3  0.015
# epoch  11:  validation loss  0.035  AP class_1  0.967  AP class_2  0.356  AP class_3  0.014
# epoch  12:  validation loss  0.036  AP class_1  0.962  AP class_2  0.455  AP class_3  0.014
# epoch  13:  validation loss  0.067  AP class_1  0.976  AP class_2  0.529  AP class_3  0.017
# epoch  14:  validation loss  0.076  AP class_1  0.978  AP class_2  0.627  AP class_3  0.015
# epoch  15:  validation loss  0.045  AP class_1  0.976  AP class_2  0.648  AP class_3  0.022
# epoch  16:  validation loss  0.036  AP class_1  0.982  AP class_2  0.669  AP class_3  0.021
# epoch  17:  validation loss  0.034  AP class_1  0.984  AP class_2  0.620  AP class_3  0.019
# epoch  18:  validation loss  0.038  AP class_1  0.982  AP class_2  0.632  AP class_3  0.018
# epoch  19:  validation loss  0.022  AP class_1  0.984  AP class_2  0.713  AP class_3  0.023
# epoch  20:  validation loss  0.023  AP class_1  0.984  AP class_2  0.730  AP class_3  0.025
# epoch  21:  validation loss  0.025  AP class_1  0.984  AP class_2  0.746  AP class_3  0.025
# epoch  22:  validation loss  0.024  AP class_1  0.983  AP class_2  0.735  AP class_3  0.027
# epoch  23:  validation loss  0.027  AP class_1  0.982  AP class_2  0.742  AP class_3  0.031
# epoch  24:  validation loss  0.031  AP class_1  0.982  AP class_2  0.742  AP class_3  0.030
# epoch  25:  validation loss  0.027  AP class_1  0.981  AP class_2  0.738  AP class_3  0.033
# epoch  26:  validation loss  0.031  AP class_1  0.979  AP class_2  0.730  AP class_3  0.030
# epoch  27:  validation loss  0.034  AP class_1  0.980  AP class_2  0.740  AP class_3  0.031
# epoch  28:  validation loss  0.037  AP class_1  0.977  AP class_2  0.743  AP class_3  0.037
# epoch  29:  validation loss  0.037  AP class_1  0.976  AP class_2  0.741  AP class_3  0.037
# epoch  30:  validation loss  0.035  AP class_1  0.976  AP class_2  0.743  AP class_3  0.037
# epoch  31:  validation loss  0.035  AP class_1  0.976  AP class_2  0.744  AP class_3  0.036
# epoch  32:  validation loss  0.035  AP class_1  0.976  AP class_2  0.743  AP class_3  0.037
# epoch  33:  validation loss  0.036  AP class_1  0.975  AP class_2  0.739  AP class_3  0.037
# epoch  34:  validation loss  0.036  AP class_1  0.976  AP class_2  0.741  AP class_3  0.039
# epoch  35:  validation loss  0.037  AP class_1  0.976  AP class_2  0.743  AP class_3  0.038
# epoch  36:  validation loss  0.038  AP class_1  0.975  AP class_2  0.738  AP class_3  0.036
# epoch  37:  validation loss  0.037  AP class_1  0.976  AP class_2  0.739  AP class_3  0.039
# epoch  38:  validation loss  0.038  AP class_1  0.975  AP class_2  0.740  AP class_3  0.038
# epoch  39:  validation loss  0.037  AP class_1  0.975  AP class_2  0.737  AP class_3  0.039
# epoch  40:  validation loss  0.039  AP class_1  0.975  AP class_2  0.740  AP class_3  0.038
# epoch  41:  validation loss  0.039  AP class_1  0.975  AP class_2  0.739  AP class_3  0.039
# epoch  42:  validation loss  0.037  AP class_1  0.976  AP class_2  0.738  AP class_3  0.038
# epoch  43:  validation loss  0.039  AP class_1  0.975  AP class_2  0.738  AP class_3  0.038
# epoch  44:  validation loss  0.037  AP class_1  0.976  AP class_2  0.737  AP class_3  0.038
# epoch  45:  validation loss  0.038  AP class_1  0.975  AP class_2  0.741  AP class_3  0.039
# epoch  46:  validation loss  0.038  AP class_1  0.976  AP class_2  0.739  AP class_3  0.038
# epoch  47:  validation loss  0.037  AP class_1  0.976  AP class_2  0.739  AP class_3  0.040
# epoch  48:  validation loss  0.038  AP class_1  0.976  AP class_2  0.739  AP class_3  0.039
# epoch  49:  validation loss  0.039  AP class_1  0.975  AP class_2  0.740  AP class_3  0.039
# epoch  50:  validation loss  0.040  AP class_1  0.974  AP class_2  0.738  AP class_3  0.037
# epoch  51:  validation loss  0.040  AP class_1  0.975  AP class_2  0.740  AP class_3  0.038

# %%
# plot the cross-entropy

plt.plot(history_df["epoch"], history_df["train_loss"], 'b-', label='Training loss')
plt.plot(history_df["epoch"], history_df["valid_loss"], 'r-', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Cross-entropy loss')
#plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy Loss')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the AUC Score

plt.plot(history_df["epoch"], history_df["AUC_class1"], 'b-', label='AUC class_1')
plt.plot(history_df["epoch"], history_df["AUC_class2"], 'r-', label='AUC class_2')
plt.plot(history_df["epoch"], history_df["AUC_class3"], 'g-', label='AUC class_3')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('AUC Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the Average Preision Score

plt.plot(history_df["epoch"], history_df["AP_class1"], 'b-', label='AP class_1')
plt.plot(history_df["epoch"], history_df["AP_class2"], 'r-', label='AP class_2')
plt.plot(history_df["epoch"], history_df["AP_class3"], 'y-', label='AP class_3')
plt.xlabel('Epoch')
plt.ylabel('AP Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Average Preision Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()
