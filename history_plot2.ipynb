# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
history_csv = "./model/history.csv"

# %%
history_df = pd.read_csv(history_csv)
history_df.head(5)
# Out:
#    epoch  train_loss  valid_loss     lr  AUC_class1  AUC_class2  AUC_class3  \
# 0    0.0    0.082669    0.082084  0.001    0.480678    0.536474    0.557202
# 1    1.0    0.053944    0.071763  0.001    0.476258    0.553040    0.479559
# 2    2.0    0.043918    0.077446  0.001    0.500856    0.526970    0.518710
# 3    3.0    0.042839    0.081406  0.001    0.557704    0.569853    0.502424
# 4    4.0    0.042570    0.083138  0.001    0.501166    0.511785    0.517193
#
#    AP_class1  AP_class2  AP_class3
# 0   0.915407   0.074875   0.023392
# 1   0.906315   0.078157   0.019645
# 2   0.913999   0.071592   0.022942
# 3   0.927392   0.085451   0.021668
# 4   0.919654   0.070657   0.024428

# %%
# %pwd

# %%
# print the epoch number, training loss, validation loss and learning rate

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']) :3d}:  training loss {row['train_loss']:6.3f}  " \
            f"validation loss {row['valid_loss']:6.3f}  " \
            f"learning rate {row['lr']:10.7f} ")
    #print(f"epoch {int(row['epoch']) :4d}")
# Out:
# epoch   0:  training loss  0.083  validation loss  0.082  learning rate  0.0010000
# epoch   1:  training loss  0.054  validation loss  0.072  learning rate  0.0010000
# epoch   2:  training loss  0.044  validation loss  0.077  learning rate  0.0010000
# epoch   3:  training loss  0.043  validation loss  0.081  learning rate  0.0010000
# epoch   4:  training loss  0.043  validation loss  0.083  learning rate  0.0010000
# epoch   5:  training loss  0.042  validation loss  0.070  learning rate  0.0010000
# epoch   6:  training loss  0.042  validation loss  0.066  learning rate  0.0010000
# epoch   7:  training loss  0.042  validation loss  0.061  learning rate  0.0010000
# epoch   8:  training loss  0.042  validation loss  0.062  learning rate  0.0010000
# epoch   9:  training loss  0.042  validation loss  0.055  learning rate  0.0010000
# epoch  10:  training loss  0.042  validation loss  0.063  learning rate  0.0010000
# epoch  11:  training loss  0.042  validation loss  0.061  learning rate  0.0010000
# epoch  12:  training loss  0.042  validation loss  0.064  learning rate  0.0010000
# epoch  13:  training loss  0.042  validation loss  0.060  learning rate  0.0010000
# epoch  14:  training loss  0.042  validation loss  0.049  learning rate  0.0010000
# epoch  15:  training loss  0.042  validation loss  0.048  learning rate  0.0010000
# epoch  16:  training loss  0.042  validation loss  0.046  learning rate  0.0010000
# epoch  17:  training loss  0.042  validation loss  0.045  learning rate  0.0010000
# epoch  18:  training loss  0.042  validation loss  0.046  learning rate  0.0010000
# epoch  19:  training loss  0.042  validation loss  0.045  learning rate  0.0010000
# epoch  20:  training loss  0.042  validation loss  0.048  learning rate  0.0010000
# epoch  21:  training loss  0.042  validation loss  0.044  learning rate  0.0010000
# epoch  22:  training loss  0.042  validation loss  0.042  learning rate  0.0010000
# epoch  23:  training loss  0.042  validation loss  0.047  learning rate  0.0010000
# epoch  24:  training loss  0.042  validation loss  0.041  learning rate  0.0010000
# epoch  25:  training loss  0.042  validation loss  0.046  learning rate  0.0010000
# epoch  26:  training loss  0.043  validation loss  0.070  learning rate  0.0010000
# epoch  27:  training loss  0.042  validation loss  0.047  learning rate  0.0010000
# epoch  28:  training loss  0.042  validation loss  0.043  learning rate  0.0010000
# epoch  29:  training loss  0.042  validation loss  0.042  learning rate  0.0010000
# epoch  30:  training loss  0.042  validation loss  0.054  learning rate  0.0010000
# epoch  31:  training loss  0.042  validation loss  0.044  learning rate  0.0010000
# epoch  32:  training loss  0.042  validation loss  0.042  learning rate  0.0010000
# epoch  33:  training loss  0.044  validation loss  0.038  learning rate  0.0001000
# epoch  34:  training loss  0.043  validation loss  0.038  learning rate  0.0001000
# epoch  35:  training loss  0.043  validation loss  0.037  learning rate  0.0001000
# epoch  36:  training loss  0.042  validation loss  0.036  learning rate  0.0001000
# epoch  37:  training loss  0.042  validation loss  0.036  learning rate  0.0001000
# epoch  38:  training loss  0.042  validation loss  0.035  learning rate  0.0001000
# epoch  39:  training loss  0.042  validation loss  0.035  learning rate  0.0001000
# epoch  40:  training loss  0.042  validation loss  0.036  learning rate  0.0001000
# epoch  41:  training loss  0.042  validation loss  0.036  learning rate  0.0001000
# epoch  42:  training loss  0.042  validation loss  0.037  learning rate  0.0001000
# epoch  43:  training loss  0.042  validation loss  0.035  learning rate  0.0001000
# epoch  44:  training loss  0.042  validation loss  0.036  learning rate  0.0001000
# epoch  45:  training loss  0.042  validation loss  0.037  learning rate  0.0001000
# epoch  46:  training loss  0.042  validation loss  0.036  learning rate  0.0001000
# epoch  47:  training loss  0.043  validation loss  0.035  learning rate  0.0000100
# epoch  48:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  49:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  50:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  51:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  52:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  53:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  54:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  55:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  56:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  57:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  58:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  59:  training loss  0.042  validation loss  0.035  learning rate  0.0000100
# epoch  60:  training loss  0.042  validation loss  0.036  learning rate  0.0000010
# epoch  61:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  62:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  63:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  64:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  65:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  66:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  67:  training loss  0.042  validation loss  0.035  learning rate  0.0000010
# epoch  68:  training loss  0.042  validation loss  0.036  learning rate  0.0000001
# epoch  69:  training loss  0.042  validation loss  0.036  learning rate  0.0000001

# %%
# print the epoch number, validation loss and AUC-Score for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AUC class_1 {row['AUC_class1']:6.3f}  " \
            f"AUC class_2 {row['AUC_class2']:6.3f}  " \
            f"AUC class_3 {row['AUC_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.082  AUC class_1  0.481  AUC class_2  0.536  AUC class_3  0.557
# epoch   1:  validation loss  0.072  AUC class_1  0.476  AUC class_2  0.553  AUC class_3  0.480
# epoch   2:  validation loss  0.077  AUC class_1  0.501  AUC class_2  0.527  AUC class_3  0.519
# epoch   3:  validation loss  0.081  AUC class_1  0.558  AUC class_2  0.570  AUC class_3  0.502
# epoch   4:  validation loss  0.083  AUC class_1  0.501  AUC class_2  0.512  AUC class_3  0.517
# epoch   5:  validation loss  0.070  AUC class_1  0.501  AUC class_2  0.520  AUC class_3  0.527
# epoch   6:  validation loss  0.066  AUC class_1  0.529  AUC class_2  0.549  AUC class_3  0.533
# epoch   7:  validation loss  0.061  AUC class_1  0.534  AUC class_2  0.547  AUC class_3  0.504
# epoch   8:  validation loss  0.062  AUC class_1  0.519  AUC class_2  0.540  AUC class_3  0.544
# epoch   9:  validation loss  0.055  AUC class_1  0.525  AUC class_2  0.539  AUC class_3  0.526
# epoch  10:  validation loss  0.063  AUC class_1  0.562  AUC class_2  0.570  AUC class_3  0.475
# epoch  11:  validation loss  0.061  AUC class_1  0.467  AUC class_2  0.506  AUC class_3  0.563
# epoch  12:  validation loss  0.064  AUC class_1  0.511  AUC class_2  0.521  AUC class_3  0.529
# epoch  13:  validation loss  0.060  AUC class_1  0.506  AUC class_2  0.514  AUC class_3  0.542
# epoch  14:  validation loss  0.049  AUC class_1  0.456  AUC class_2  0.463  AUC class_3  0.568
# epoch  15:  validation loss  0.048  AUC class_1  0.461  AUC class_2  0.471  AUC class_3  0.526
# epoch  16:  validation loss  0.046  AUC class_1  0.456  AUC class_2  0.471  AUC class_3  0.539
# epoch  17:  validation loss  0.045  AUC class_1  0.499  AUC class_2  0.531  AUC class_3  0.519
# epoch  18:  validation loss  0.046  AUC class_1  0.555  AUC class_2  0.545  AUC class_3  0.474
# epoch  19:  validation loss  0.045  AUC class_1  0.519  AUC class_2  0.534  AUC class_3  0.501
# epoch  20:  validation loss  0.048  AUC class_1  0.508  AUC class_2  0.516  AUC class_3  0.498
# epoch  21:  validation loss  0.044  AUC class_1  0.513  AUC class_2  0.519  AUC class_3  0.492
# epoch  22:  validation loss  0.042  AUC class_1  0.503  AUC class_2  0.505  AUC class_3  0.498
# epoch  23:  validation loss  0.047  AUC class_1  0.493  AUC class_2  0.511  AUC class_3  0.540
# epoch  24:  validation loss  0.041  AUC class_1  0.503  AUC class_2  0.505  AUC class_3  0.493
# epoch  25:  validation loss  0.046  AUC class_1  0.504  AUC class_2  0.490  AUC class_3  0.524
# epoch  26:  validation loss  0.070  AUC class_1  0.503  AUC class_2  0.501  AUC class_3  0.524
# epoch  27:  validation loss  0.047  AUC class_1  0.525  AUC class_2  0.516  AUC class_3  0.505
# epoch  28:  validation loss  0.043  AUC class_1  0.575  AUC class_2  0.529  AUC class_3  0.464
# epoch  29:  validation loss  0.042  AUC class_1  0.589  AUC class_2  0.577  AUC class_3  0.477
# epoch  30:  validation loss  0.054  AUC class_1  0.533  AUC class_2  0.508  AUC class_3  0.495
# epoch  31:  validation loss  0.044  AUC class_1  0.532  AUC class_2  0.474  AUC class_3  0.528
# epoch  32:  validation loss  0.042  AUC class_1  0.506  AUC class_2  0.512  AUC class_3  0.486
# epoch  33:  validation loss  0.038  AUC class_1  0.503  AUC class_2  0.508  AUC class_3  0.485
# epoch  34:  validation loss  0.038  AUC class_1  0.502  AUC class_2  0.506  AUC class_3  0.491
# epoch  35:  validation loss  0.037  AUC class_1  0.501  AUC class_2  0.503  AUC class_3  0.486
# epoch  36:  validation loss  0.036  AUC class_1  0.497  AUC class_2  0.502  AUC class_3  0.489
# epoch  37:  validation loss  0.036  AUC class_1  0.495  AUC class_2  0.510  AUC class_3  0.507
# epoch  38:  validation loss  0.035  AUC class_1  0.497  AUC class_2  0.512  AUC class_3  0.506
# epoch  39:  validation loss  0.035  AUC class_1  0.477  AUC class_2  0.506  AUC class_3  0.548
# epoch  40:  validation loss  0.036  AUC class_1  0.488  AUC class_2  0.493  AUC class_3  0.538
# epoch  41:  validation loss  0.036  AUC class_1  0.489  AUC class_2  0.488  AUC class_3  0.544
# epoch  42:  validation loss  0.037  AUC class_1  0.490  AUC class_2  0.484  AUC class_3  0.538
# epoch  43:  validation loss  0.035  AUC class_1  0.489  AUC class_2  0.493  AUC class_3  0.541
# epoch  44:  validation loss  0.036  AUC class_1  0.492  AUC class_2  0.494  AUC class_3  0.548
# epoch  45:  validation loss  0.037  AUC class_1  0.494  AUC class_2  0.502  AUC class_3  0.544
# epoch  46:  validation loss  0.036  AUC class_1  0.500  AUC class_2  0.509  AUC class_3  0.543
# epoch  47:  validation loss  0.035  AUC class_1  0.501  AUC class_2  0.509  AUC class_3  0.539
# epoch  48:  validation loss  0.035  AUC class_1  0.500  AUC class_2  0.507  AUC class_3  0.541
# epoch  49:  validation loss  0.035  AUC class_1  0.488  AUC class_2  0.489  AUC class_3  0.551
# epoch  50:  validation loss  0.035  AUC class_1  0.500  AUC class_2  0.504  AUC class_3  0.540
# epoch  51:  validation loss  0.035  AUC class_1  0.495  AUC class_2  0.501  AUC class_3  0.506
# epoch  52:  validation loss  0.035  AUC class_1  0.498  AUC class_2  0.503  AUC class_3  0.501
# epoch  53:  validation loss  0.035  AUC class_1  0.505  AUC class_2  0.507  AUC class_3  0.511
# epoch  54:  validation loss  0.035  AUC class_1  0.500  AUC class_2  0.501  AUC class_3  0.504
# epoch  55:  validation loss  0.035  AUC class_1  0.497  AUC class_2  0.502  AUC class_3  0.505
# epoch  56:  validation loss  0.035  AUC class_1  0.498  AUC class_2  0.502  AUC class_3  0.509
# epoch  57:  validation loss  0.035  AUC class_1  0.490  AUC class_2  0.501  AUC class_3  0.521
# epoch  58:  validation loss  0.035  AUC class_1  0.485  AUC class_2  0.490  AUC class_3  0.531
# epoch  59:  validation loss  0.035  AUC class_1  0.497  AUC class_2  0.503  AUC class_3  0.509
# epoch  60:  validation loss  0.036  AUC class_1  0.481  AUC class_2  0.487  AUC class_3  0.539
# epoch  61:  validation loss  0.035  AUC class_1  0.485  AUC class_2  0.488  AUC class_3  0.549
# epoch  62:  validation loss  0.035  AUC class_1  0.504  AUC class_2  0.509  AUC class_3  0.512
# epoch  63:  validation loss  0.035  AUC class_1  0.488  AUC class_2  0.491  AUC class_3  0.550
# epoch  64:  validation loss  0.035  AUC class_1  0.501  AUC class_2  0.502  AUC class_3  0.507
# epoch  65:  validation loss  0.035  AUC class_1  0.502  AUC class_2  0.504  AUC class_3  0.508
# epoch  66:  validation loss  0.035  AUC class_1  0.503  AUC class_2  0.506  AUC class_3  0.508
# epoch  67:  validation loss  0.035  AUC class_1  0.503  AUC class_2  0.506  AUC class_3  0.520
# epoch  68:  validation loss  0.036  AUC class_1  0.495  AUC class_2  0.496  AUC class_3  0.548
# epoch  69:  validation loss  0.036  AUC class_1  0.494  AUC class_2  0.494  AUC class_3  0.548

# %%
# print the epoch number, validation loss and Average Precision for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AP class_1 {row['AP_class1']:6.3f}  " \
            f"AP class_2 {row['AP_class2']:6.3f}  " \
            f"AP class_3 {row['AP_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.082  AP class_1  0.915  AP class_2  0.075  AP class_3  0.023
# epoch   1:  validation loss  0.072  AP class_1  0.906  AP class_2  0.078  AP class_3  0.020
# epoch   2:  validation loss  0.077  AP class_1  0.914  AP class_2  0.072  AP class_3  0.023
# epoch   3:  validation loss  0.081  AP class_1  0.927  AP class_2  0.085  AP class_3  0.022
# epoch   4:  validation loss  0.083  AP class_1  0.920  AP class_2  0.071  AP class_3  0.024
# epoch   5:  validation loss  0.070  AP class_1  0.919  AP class_2  0.070  AP class_3  0.023
# epoch   6:  validation loss  0.066  AP class_1  0.924  AP class_2  0.077  AP class_3  0.023
# epoch   7:  validation loss  0.061  AP class_1  0.924  AP class_2  0.084  AP class_3  0.020
# epoch   8:  validation loss  0.062  AP class_1  0.923  AP class_2  0.078  AP class_3  0.023
# epoch   9:  validation loss  0.055  AP class_1  0.922  AP class_2  0.081  AP class_3  0.021
# epoch  10:  validation loss  0.063  AP class_1  0.929  AP class_2  0.088  AP class_3  0.019
# epoch  11:  validation loss  0.061  AP class_1  0.912  AP class_2  0.069  AP class_3  0.024
# epoch  12:  validation loss  0.064  AP class_1  0.922  AP class_2  0.075  AP class_3  0.022
# epoch  13:  validation loss  0.060  AP class_1  0.920  AP class_2  0.074  AP class_3  0.024
# epoch  14:  validation loss  0.049  AP class_1  0.913  AP class_2  0.059  AP class_3  0.025
# epoch  15:  validation loss  0.048  AP class_1  0.912  AP class_2  0.060  AP class_3  0.022
# epoch  16:  validation loss  0.046  AP class_1  0.910  AP class_2  0.064  AP class_3  0.022
# epoch  17:  validation loss  0.045  AP class_1  0.918  AP class_2  0.076  AP class_3  0.021
# epoch  18:  validation loss  0.046  AP class_1  0.924  AP class_2  0.080  AP class_3  0.019
# epoch  19:  validation loss  0.045  AP class_1  0.920  AP class_2  0.074  AP class_3  0.020
# epoch  20:  validation loss  0.048  AP class_1  0.920  AP class_2  0.068  AP class_3  0.020
# epoch  21:  validation loss  0.044  AP class_1  0.917  AP class_2  0.069  AP class_3  0.019
# epoch  22:  validation loss  0.042  AP class_1  0.914  AP class_2  0.067  AP class_3  0.020
# epoch  23:  validation loss  0.047  AP class_1  0.918  AP class_2  0.066  AP class_3  0.022
# epoch  24:  validation loss  0.041  AP class_1  0.915  AP class_2  0.067  AP class_3  0.020
# epoch  25:  validation loss  0.046  AP class_1  0.918  AP class_2  0.063  AP class_3  0.021
# epoch  26:  validation loss  0.070  AP class_1  0.919  AP class_2  0.066  AP class_3  0.021
# epoch  27:  validation loss  0.047  AP class_1  0.922  AP class_2  0.070  AP class_3  0.020
# epoch  28:  validation loss  0.043  AP class_1  0.928  AP class_2  0.072  AP class_3  0.018
# epoch  29:  validation loss  0.042  AP class_1  0.931  AP class_2  0.081  AP class_3  0.019
# epoch  30:  validation loss  0.054  AP class_1  0.921  AP class_2  0.067  AP class_3  0.020
# epoch  31:  validation loss  0.044  AP class_1  0.920  AP class_2  0.062  AP class_3  0.021
# epoch  32:  validation loss  0.042  AP class_1  0.916  AP class_2  0.068  AP class_3  0.019
# epoch  33:  validation loss  0.038  AP class_1  0.915  AP class_2  0.067  AP class_3  0.019
# epoch  34:  validation loss  0.038  AP class_1  0.914  AP class_2  0.067  AP class_3  0.019
# epoch  35:  validation loss  0.037  AP class_1  0.914  AP class_2  0.067  AP class_3  0.019
# epoch  36:  validation loss  0.036  AP class_1  0.914  AP class_2  0.067  AP class_3  0.019
# epoch  37:  validation loss  0.036  AP class_1  0.914  AP class_2  0.068  AP class_3  0.020
# epoch  38:  validation loss  0.035  AP class_1  0.914  AP class_2  0.068  AP class_3  0.020
# epoch  39:  validation loss  0.035  AP class_1  0.912  AP class_2  0.067  AP class_3  0.023
# epoch  40:  validation loss  0.036  AP class_1  0.914  AP class_2  0.065  AP class_3  0.022
# epoch  41:  validation loss  0.036  AP class_1  0.914  AP class_2  0.065  AP class_3  0.022
# epoch  42:  validation loss  0.037  AP class_1  0.914  AP class_2  0.063  AP class_3  0.021
# epoch  43:  validation loss  0.035  AP class_1  0.914  AP class_2  0.065  AP class_3  0.022
# epoch  44:  validation loss  0.036  AP class_1  0.916  AP class_2  0.064  AP class_3  0.022
# epoch  45:  validation loss  0.037  AP class_1  0.916  AP class_2  0.066  AP class_3  0.022
# epoch  46:  validation loss  0.036  AP class_1  0.917  AP class_2  0.067  AP class_3  0.022
# epoch  47:  validation loss  0.035  AP class_1  0.917  AP class_2  0.068  AP class_3  0.021
# epoch  48:  validation loss  0.035  AP class_1  0.917  AP class_2  0.067  AP class_3  0.022
# epoch  49:  validation loss  0.035  AP class_1  0.914  AP class_2  0.064  AP class_3  0.023
# epoch  50:  validation loss  0.035  AP class_1  0.917  AP class_2  0.067  AP class_3  0.022
# epoch  51:  validation loss  0.035  AP class_1  0.914  AP class_2  0.067  AP class_3  0.020
# epoch  52:  validation loss  0.035  AP class_1  0.914  AP class_2  0.067  AP class_3  0.020
# epoch  53:  validation loss  0.035  AP class_1  0.915  AP class_2  0.066  AP class_3  0.020
# epoch  54:  validation loss  0.035  AP class_1  0.915  AP class_2  0.066  AP class_3  0.020
# epoch  55:  validation loss  0.035  AP class_1  0.914  AP class_2  0.067  AP class_3  0.020
# epoch  56:  validation loss  0.035  AP class_1  0.914  AP class_2  0.067  AP class_3  0.020
# epoch  57:  validation loss  0.035  AP class_1  0.912  AP class_2  0.067  AP class_3  0.021
# epoch  58:  validation loss  0.035  AP class_1  0.912  AP class_2  0.065  AP class_3  0.022
# epoch  59:  validation loss  0.035  AP class_1  0.914  AP class_2  0.067  AP class_3  0.020
# epoch  60:  validation loss  0.036  AP class_1  0.912  AP class_2  0.064  AP class_3  0.022
# epoch  61:  validation loss  0.035  AP class_1  0.914  AP class_2  0.064  AP class_3  0.022
# epoch  62:  validation loss  0.035  AP class_1  0.915  AP class_2  0.067  AP class_3  0.020
# epoch  63:  validation loss  0.035  AP class_1  0.914  AP class_2  0.065  AP class_3  0.022
# epoch  64:  validation loss  0.035  AP class_1  0.915  AP class_2  0.066  AP class_3  0.020
# epoch  65:  validation loss  0.035  AP class_1  0.915  AP class_2  0.066  AP class_3  0.020
# epoch  66:  validation loss  0.035  AP class_1  0.915  AP class_2  0.066  AP class_3  0.020
# epoch  67:  validation loss  0.035  AP class_1  0.915  AP class_2  0.067  AP class_3  0.021
# epoch  68:  validation loss  0.036  AP class_1  0.916  AP class_2  0.065  AP class_3  0.022
# epoch  69:  validation loss  0.036  AP class_1  0.915  AP class_2  0.065  AP class_3  0.022

# %%
# plot the cross-entropy

plt.plot(history_df["epoch"], history_df["train_loss"], 'b-', label='Training loss')
plt.plot(history_df["epoch"], history_df["valid_loss"], 'r-', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Cross-entropy loss')
#plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy Loss')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the AUC Score

plt.plot(history_df["epoch"], history_df["AUC_class1"], 'b-', label='AUC class_1')
plt.plot(history_df["epoch"], history_df["AUC_class2"], 'r-', label='AUC class_2')
plt.plot(history_df["epoch"], history_df["AUC_class3"], 'g-', label='AUC class_3')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('AUC Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the Average Preision Score

plt.plot(history_df["epoch"], history_df["AP_class1"], 'b-', label='AP class_1')
plt.plot(history_df["epoch"], history_df["AP_class2"], 'r-', label='AP class_2')
plt.plot(history_df["epoch"], history_df["AP_class3"], 'y-', label='AP class_3')
plt.xlabel('Epoch')
plt.ylabel('AP Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Average Preision Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()
