# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
history_csv = "./previousModel/model_17Mar_weight/history.csv"

# %%
history_df = pd.read_csv(history_csv)
history_df.head(5)
# Out:
#    epoch  train_loss  valid_loss     lr  AUC_class1  AUC_class2  AUC_class3  \
# 0    0.0    0.234630    0.244389  0.001    0.454812    0.564723    0.518144
# 1    1.0    0.171533    0.262315  0.001    0.493829    0.510585    0.514223
# 2    2.0    0.132831    0.197061  0.001    0.535252    0.524103    0.485111
# 3    3.0    0.105892    0.153575  0.001    0.532079    0.557227    0.489930
# 4    4.0    0.104322    0.137656  0.001    0.512116    0.525871    0.500667
#
#    AP_class1  AP_class2  AP_class3
# 0   0.903534   0.083724   0.021685
# 1   0.912188   0.066524   0.021829
# 2   0.918648   0.072283   0.019622
# 3   0.919772   0.081573   0.019103
# 4   0.914145   0.074527   0.020172

# %%
# %pwd

# %%
# print the epoch number, training loss, validation loss and learning rate

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']) :3d}:  training loss {row['train_loss']:6.3f}  " \
            f"validation loss {row['valid_loss']:6.3f}  " \
            f"learning rate {row['lr']:10.7f} ")
    #print(f"epoch {int(row['epoch']) :4d}")
# Out:
# epoch   0:  training loss  0.235  validation loss  0.244  learning rate  0.0010000
# epoch   1:  training loss  0.172  validation loss  0.262  learning rate  0.0010000
# epoch   2:  training loss  0.133  validation loss  0.197  learning rate  0.0010000
# epoch   3:  training loss  0.106  validation loss  0.154  learning rate  0.0010000
# epoch   4:  training loss  0.104  validation loss  0.138  learning rate  0.0010000
# epoch   5:  training loss  0.104  validation loss  0.116  learning rate  0.0010000
# epoch   6:  training loss  0.104  validation loss  0.121  learning rate  0.0010000
# epoch   7:  training loss  0.104  validation loss  0.104  learning rate  0.0010000
# epoch   8:  training loss  0.105  validation loss  0.109  learning rate  0.0010000
# epoch   9:  training loss  0.103  validation loss  0.102  learning rate  0.0010000
# epoch  10:  training loss  0.104  validation loss  0.099  learning rate  0.0010000
# epoch  11:  training loss  0.103  validation loss  0.111  learning rate  0.0010000
# epoch  12:  training loss  0.104  validation loss  0.107  learning rate  0.0010000
# epoch  13:  training loss  0.103  validation loss  0.107  learning rate  0.0010000
# epoch  14:  training loss  0.104  validation loss  0.105  learning rate  0.0010000
# epoch  15:  training loss  0.103  validation loss  0.127  learning rate  0.0010000
# epoch  16:  training loss  0.104  validation loss  0.174  learning rate  0.0010000
# epoch  17:  training loss  0.103  validation loss  0.119  learning rate  0.0010000
# epoch  18:  training loss  0.103  validation loss  0.156  learning rate  0.0010000
# epoch  19:  training loss  0.105  validation loss  0.110  learning rate  0.0001000
# epoch  20:  training loss  0.103  validation loss  0.116  learning rate  0.0001000
# epoch  21:  training loss  0.103  validation loss  0.114  learning rate  0.0001000
# epoch  22:  training loss  0.103  validation loss  0.098  learning rate  0.0001000
# epoch  23:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  24:  training loss  0.103  validation loss  0.100  learning rate  0.0001000
# epoch  25:  training loss  0.103  validation loss  0.098  learning rate  0.0001000
# epoch  26:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  27:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  28:  training loss  0.103  validation loss  0.098  learning rate  0.0001000
# epoch  29:  training loss  0.103  validation loss  0.097  learning rate  0.0001000
# epoch  30:  training loss  0.103  validation loss  0.100  learning rate  0.0001000
# epoch  31:  training loss  0.103  validation loss  0.100  learning rate  0.0001000
# epoch  32:  training loss  0.103  validation loss  0.098  learning rate  0.0001000
# epoch  33:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  34:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  35:  training loss  0.103  validation loss  0.100  learning rate  0.0001000
# epoch  36:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  37:  training loss  0.103  validation loss  0.099  learning rate  0.0001000
# epoch  38:  training loss  0.104  validation loss  0.097  learning rate  0.0000100
# epoch  39:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  40:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  41:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  42:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  43:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  44:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  45:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  46:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  47:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  48:  training loss  0.103  validation loss  0.097  learning rate  0.0000100
# epoch  49:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  50:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  51:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  52:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  53:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  54:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  55:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  56:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  57:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  58:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  59:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  60:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  61:  training loss  0.103  validation loss  0.096  learning rate  0.0000100
# epoch  62:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  63:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  64:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  65:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  66:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  67:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  68:  training loss  0.103  validation loss  0.096  learning rate  0.0000010
# epoch  69:  training loss  0.103  validation loss  0.096  learning rate  0.0000010

# %%
# print the epoch number, validation loss and AUC-Score for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AUC class_1 {row['AUC_class1']:6.3f}  " \
            f"AUC class_2 {row['AUC_class2']:6.3f}  " \
            f"AUC class_3 {row['AUC_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.244  AUC class_1  0.455  AUC class_2  0.565  AUC class_3  0.518
# epoch   1:  validation loss  0.262  AUC class_1  0.494  AUC class_2  0.511  AUC class_3  0.514
# epoch   2:  validation loss  0.197  AUC class_1  0.535  AUC class_2  0.524  AUC class_3  0.485
# epoch   3:  validation loss  0.154  AUC class_1  0.532  AUC class_2  0.557  AUC class_3  0.490
# epoch   4:  validation loss  0.138  AUC class_1  0.512  AUC class_2  0.526  AUC class_3  0.501
# epoch   5:  validation loss  0.116  AUC class_1  0.505  AUC class_2  0.529  AUC class_3  0.504
# epoch   6:  validation loss  0.121  AUC class_1  0.507  AUC class_2  0.512  AUC class_3  0.544
# epoch   7:  validation loss  0.104  AUC class_1  0.565  AUC class_2  0.592  AUC class_3  0.503
# epoch   8:  validation loss  0.109  AUC class_1  0.491  AUC class_2  0.508  AUC class_3  0.497
# epoch   9:  validation loss  0.102  AUC class_1  0.492  AUC class_2  0.507  AUC class_3  0.539
# epoch  10:  validation loss  0.099  AUC class_1  0.516  AUC class_2  0.509  AUC class_3  0.494
# epoch  11:  validation loss  0.111  AUC class_1  0.564  AUC class_2  0.557  AUC class_3  0.506
# epoch  12:  validation loss  0.107  AUC class_1  0.540  AUC class_2  0.556  AUC class_3  0.540
# epoch  13:  validation loss  0.107  AUC class_1  0.542  AUC class_2  0.552  AUC class_3  0.504
# epoch  14:  validation loss  0.105  AUC class_1  0.534  AUC class_2  0.532  AUC class_3  0.514
# epoch  15:  validation loss  0.127  AUC class_1  0.524  AUC class_2  0.528  AUC class_3  0.518
# epoch  16:  validation loss  0.174  AUC class_1  0.518  AUC class_2  0.515  AUC class_3  0.525
# epoch  17:  validation loss  0.119  AUC class_1  0.558  AUC class_2  0.561  AUC class_3  0.494
# epoch  18:  validation loss  0.156  AUC class_1  0.513  AUC class_2  0.499  AUC class_3  0.508
# epoch  19:  validation loss  0.110  AUC class_1  0.530  AUC class_2  0.534  AUC class_3  0.502
# epoch  20:  validation loss  0.116  AUC class_1  0.535  AUC class_2  0.538  AUC class_3  0.504
# epoch  21:  validation loss  0.114  AUC class_1  0.535  AUC class_2  0.527  AUC class_3  0.502
# epoch  22:  validation loss  0.098  AUC class_1  0.529  AUC class_2  0.533  AUC class_3  0.503
# epoch  23:  validation loss  0.099  AUC class_1  0.531  AUC class_2  0.527  AUC class_3  0.507
# epoch  24:  validation loss  0.100  AUC class_1  0.530  AUC class_2  0.537  AUC class_3  0.511
# epoch  25:  validation loss  0.098  AUC class_1  0.529  AUC class_2  0.540  AUC class_3  0.510
# epoch  26:  validation loss  0.099  AUC class_1  0.525  AUC class_2  0.526  AUC class_3  0.515
# epoch  27:  validation loss  0.099  AUC class_1  0.525  AUC class_2  0.537  AUC class_3  0.509
# epoch  28:  validation loss  0.098  AUC class_1  0.523  AUC class_2  0.541  AUC class_3  0.515
# epoch  29:  validation loss  0.097  AUC class_1  0.522  AUC class_2  0.540  AUC class_3  0.517
# epoch  30:  validation loss  0.100  AUC class_1  0.522  AUC class_2  0.537  AUC class_3  0.510
# epoch  31:  validation loss  0.100  AUC class_1  0.519  AUC class_2  0.536  AUC class_3  0.512
# epoch  32:  validation loss  0.098  AUC class_1  0.520  AUC class_2  0.536  AUC class_3  0.523
# epoch  33:  validation loss  0.099  AUC class_1  0.522  AUC class_2  0.530  AUC class_3  0.520
# epoch  34:  validation loss  0.099  AUC class_1  0.527  AUC class_2  0.538  AUC class_3  0.508
# epoch  35:  validation loss  0.100  AUC class_1  0.520  AUC class_2  0.534  AUC class_3  0.517
# epoch  36:  validation loss  0.099  AUC class_1  0.517  AUC class_2  0.524  AUC class_3  0.523
# epoch  37:  validation loss  0.099  AUC class_1  0.523  AUC class_2  0.532  AUC class_3  0.519
# epoch  38:  validation loss  0.097  AUC class_1  0.524  AUC class_2  0.535  AUC class_3  0.515
# epoch  39:  validation loss  0.097  AUC class_1  0.524  AUC class_2  0.537  AUC class_3  0.511
# epoch  40:  validation loss  0.097  AUC class_1  0.525  AUC class_2  0.537  AUC class_3  0.510
# epoch  41:  validation loss  0.097  AUC class_1  0.531  AUC class_2  0.544  AUC class_3  0.513
# epoch  42:  validation loss  0.097  AUC class_1  0.526  AUC class_2  0.529  AUC class_3  0.509
# epoch  43:  validation loss  0.097  AUC class_1  0.526  AUC class_2  0.528  AUC class_3  0.509
# epoch  44:  validation loss  0.097  AUC class_1  0.526  AUC class_2  0.524  AUC class_3  0.508
# epoch  45:  validation loss  0.097  AUC class_1  0.526  AUC class_2  0.525  AUC class_3  0.512
# epoch  46:  validation loss  0.097  AUC class_1  0.527  AUC class_2  0.522  AUC class_3  0.515
# epoch  47:  validation loss  0.096  AUC class_1  0.526  AUC class_2  0.520  AUC class_3  0.516
# epoch  48:  validation loss  0.097  AUC class_1  0.524  AUC class_2  0.523  AUC class_3  0.514
# epoch  49:  validation loss  0.096  AUC class_1  0.524  AUC class_2  0.522  AUC class_3  0.516
# epoch  50:  validation loss  0.096  AUC class_1  0.528  AUC class_2  0.521  AUC class_3  0.515
# epoch  51:  validation loss  0.096  AUC class_1  0.530  AUC class_2  0.526  AUC class_3  0.516
# epoch  52:  validation loss  0.096  AUC class_1  0.523  AUC class_2  0.522  AUC class_3  0.513
# epoch  53:  validation loss  0.096  AUC class_1  0.525  AUC class_2  0.520  AUC class_3  0.515
# epoch  54:  validation loss  0.096  AUC class_1  0.521  AUC class_2  0.523  AUC class_3  0.507
# epoch  55:  validation loss  0.096  AUC class_1  0.523  AUC class_2  0.520  AUC class_3  0.513
# epoch  56:  validation loss  0.096  AUC class_1  0.524  AUC class_2  0.519  AUC class_3  0.515
# epoch  57:  validation loss  0.096  AUC class_1  0.523  AUC class_2  0.518  AUC class_3  0.515
# epoch  58:  validation loss  0.096  AUC class_1  0.522  AUC class_2  0.519  AUC class_3  0.516
# epoch  59:  validation loss  0.096  AUC class_1  0.525  AUC class_2  0.522  AUC class_3  0.517
# epoch  60:  validation loss  0.096  AUC class_1  0.522  AUC class_2  0.515  AUC class_3  0.518
# epoch  61:  validation loss  0.096  AUC class_1  0.525  AUC class_2  0.519  AUC class_3  0.519
# epoch  62:  validation loss  0.096  AUC class_1  0.530  AUC class_2  0.522  AUC class_3  0.514
# epoch  63:  validation loss  0.096  AUC class_1  0.529  AUC class_2  0.524  AUC class_3  0.515
# epoch  64:  validation loss  0.096  AUC class_1  0.526  AUC class_2  0.523  AUC class_3  0.515
# epoch  65:  validation loss  0.096  AUC class_1  0.528  AUC class_2  0.522  AUC class_3  0.513
# epoch  66:  validation loss  0.096  AUC class_1  0.526  AUC class_2  0.520  AUC class_3  0.518
# epoch  67:  validation loss  0.096  AUC class_1  0.529  AUC class_2  0.519  AUC class_3  0.512
# epoch  68:  validation loss  0.096  AUC class_1  0.525  AUC class_2  0.521  AUC class_3  0.518
# epoch  69:  validation loss  0.096  AUC class_1  0.528  AUC class_2  0.525  AUC class_3  0.514

# %%
# print the epoch number, validation loss and Average Precision for each class

for index, row in history_df.iterrows():
    print(f"epoch {int(row['epoch']):3d}:  validation loss {row['valid_loss']:6.3f}  " \
            f"AP class_1 {row['AP_class1']:6.3f}  " \
            f"AP class_2 {row['AP_class2']:6.3f}  " \
            f"AP class_3 {row['AP_class3']:6.3f}")
# Out:
# epoch   0:  validation loss  0.244  AP class_1  0.904  AP class_2  0.084  AP class_3  0.022
# epoch   1:  validation loss  0.262  AP class_1  0.912  AP class_2  0.067  AP class_3  0.022
# epoch   2:  validation loss  0.197  AP class_1  0.919  AP class_2  0.072  AP class_3  0.020
# epoch   3:  validation loss  0.154  AP class_1  0.920  AP class_2  0.082  AP class_3  0.019
# epoch   4:  validation loss  0.138  AP class_1  0.914  AP class_2  0.075  AP class_3  0.020
# epoch   5:  validation loss  0.116  AP class_1  0.916  AP class_2  0.088  AP class_3  0.020
# epoch   6:  validation loss  0.121  AP class_1  0.914  AP class_2  0.071  AP class_3  0.022
# epoch   7:  validation loss  0.104  AP class_1  0.924  AP class_2  0.093  AP class_3  0.020
# epoch   8:  validation loss  0.109  AP class_1  0.911  AP class_2  0.069  AP class_3  0.020
# epoch   9:  validation loss  0.102  AP class_1  0.914  AP class_2  0.067  AP class_3  0.021
# epoch  10:  validation loss  0.099  AP class_1  0.919  AP class_2  0.072  AP class_3  0.019
# epoch  11:  validation loss  0.111  AP class_1  0.928  AP class_2  0.085  AP class_3  0.020
# epoch  12:  validation loss  0.107  AP class_1  0.925  AP class_2  0.086  AP class_3  0.021
# epoch  13:  validation loss  0.107  AP class_1  0.924  AP class_2  0.083  AP class_3  0.020
# epoch  14:  validation loss  0.105  AP class_1  0.922  AP class_2  0.078  AP class_3  0.020
# epoch  15:  validation loss  0.127  AP class_1  0.921  AP class_2  0.072  AP class_3  0.020
# epoch  16:  validation loss  0.174  AP class_1  0.922  AP class_2  0.069  AP class_3  0.021
# epoch  17:  validation loss  0.119  AP class_1  0.925  AP class_2  0.098  AP class_3  0.019
# epoch  18:  validation loss  0.156  AP class_1  0.920  AP class_2  0.069  AP class_3  0.020
# epoch  19:  validation loss  0.110  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  20:  validation loss  0.116  AP class_1  0.923  AP class_2  0.077  AP class_3  0.020
# epoch  21:  validation loss  0.114  AP class_1  0.923  AP class_2  0.074  AP class_3  0.020
# epoch  22:  validation loss  0.098  AP class_1  0.922  AP class_2  0.076  AP class_3  0.020
# epoch  23:  validation loss  0.099  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  24:  validation loss  0.100  AP class_1  0.922  AP class_2  0.077  AP class_3  0.020
# epoch  25:  validation loss  0.098  AP class_1  0.923  AP class_2  0.078  AP class_3  0.020
# epoch  26:  validation loss  0.099  AP class_1  0.922  AP class_2  0.074  AP class_3  0.020
# epoch  27:  validation loss  0.099  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  28:  validation loss  0.098  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  29:  validation loss  0.097  AP class_1  0.921  AP class_2  0.075  AP class_3  0.020
# epoch  30:  validation loss  0.100  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  31:  validation loss  0.100  AP class_1  0.921  AP class_2  0.075  AP class_3  0.020
# epoch  32:  validation loss  0.098  AP class_1  0.921  AP class_2  0.075  AP class_3  0.021
# epoch  33:  validation loss  0.099  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  34:  validation loss  0.099  AP class_1  0.922  AP class_2  0.076  AP class_3  0.020
# epoch  35:  validation loss  0.100  AP class_1  0.921  AP class_2  0.075  AP class_3  0.020
# epoch  36:  validation loss  0.099  AP class_1  0.921  AP class_2  0.075  AP class_3  0.021
# epoch  37:  validation loss  0.099  AP class_1  0.921  AP class_2  0.075  AP class_3  0.020
# epoch  38:  validation loss  0.097  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  39:  validation loss  0.097  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  40:  validation loss  0.097  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  41:  validation loss  0.097  AP class_1  0.923  AP class_2  0.078  AP class_3  0.020
# epoch  42:  validation loss  0.097  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  43:  validation loss  0.097  AP class_1  0.922  AP class_2  0.076  AP class_3  0.020
# epoch  44:  validation loss  0.097  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  45:  validation loss  0.097  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  46:  validation loss  0.097  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  47:  validation loss  0.096  AP class_1  0.922  AP class_2  0.074  AP class_3  0.020
# epoch  48:  validation loss  0.097  AP class_1  0.921  AP class_2  0.076  AP class_3  0.020
# epoch  49:  validation loss  0.096  AP class_1  0.921  AP class_2  0.075  AP class_3  0.020
# epoch  50:  validation loss  0.096  AP class_1  0.922  AP class_2  0.074  AP class_3  0.020
# epoch  51:  validation loss  0.096  AP class_1  0.923  AP class_2  0.076  AP class_3  0.020
# epoch  52:  validation loss  0.096  AP class_1  0.921  AP class_2  0.074  AP class_3  0.020
# epoch  53:  validation loss  0.096  AP class_1  0.921  AP class_2  0.074  AP class_3  0.020
# epoch  54:  validation loss  0.096  AP class_1  0.921  AP class_2  0.075  AP class_3  0.020
# epoch  55:  validation loss  0.096  AP class_1  0.921  AP class_2  0.074  AP class_3  0.020
# epoch  56:  validation loss  0.096  AP class_1  0.921  AP class_2  0.074  AP class_3  0.020
# epoch  57:  validation loss  0.096  AP class_1  0.921  AP class_2  0.074  AP class_3  0.020
# epoch  58:  validation loss  0.096  AP class_1  0.921  AP class_2  0.074  AP class_3  0.020
# epoch  59:  validation loss  0.096  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  60:  validation loss  0.096  AP class_1  0.921  AP class_2  0.073  AP class_3  0.020
# epoch  61:  validation loss  0.096  AP class_1  0.922  AP class_2  0.074  AP class_3  0.020
# epoch  62:  validation loss  0.096  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  63:  validation loss  0.096  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  64:  validation loss  0.096  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  65:  validation loss  0.096  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  66:  validation loss  0.096  AP class_1  0.922  AP class_2  0.074  AP class_3  0.020
# epoch  67:  validation loss  0.096  AP class_1  0.922  AP class_2  0.075  AP class_3  0.020
# epoch  68:  validation loss  0.096  AP class_1  0.922  AP class_2  0.074  AP class_3  0.020
# epoch  69:  validation loss  0.096  AP class_1  0.923  AP class_2  0.076  AP class_3  0.020

# %%
# plot the cross-entropy

plt.plot(history_df["epoch"], history_df["train_loss"], 'b-', label='Training loss')
plt.plot(history_df["epoch"], history_df["valid_loss"], 'r-', label='Validation loss')
plt.xlabel('Epoch')
plt.ylabel('Cross-entropy loss')
#plt.ylim([0, min(test_crossentropy) * 3])
plt.title('Cross-entropy Loss')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the AUC Score

plt.plot(history_df["epoch"], history_df["AUC_class1"], 'b-', label='AUC class_1')
plt.plot(history_df["epoch"], history_df["AUC_class2"], 'r-', label='AUC class_2')
plt.plot(history_df["epoch"], history_df["AUC_class3"], 'g-', label='AUC class_3')
plt.xlabel('Epoch')
plt.ylabel('AUC Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('AUC Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()

# plot the Average Preision Score

plt.plot(history_df["epoch"], history_df["AP_class1"], 'b-', label='AP class_1')
plt.plot(history_df["epoch"], history_df["AP_class2"], 'r-', label='AP class_2')
plt.plot(history_df["epoch"], history_df["AP_class3"], 'y-', label='AP class_3')
plt.xlabel('Epoch')
plt.ylabel('AP Score')
#plt.ylim([max(1 - (1 - test_accuracy[-1]) * 2, 0), 1])
plt.title('Average Preision Score for Each Class')
plt.grid(True)
plt.legend(loc='best')
plt.show()
